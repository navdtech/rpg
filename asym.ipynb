# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
T = np.loadtxt('rT_U_1_A10')

# %%
plt.figure(figsize=(12,4))
plt.plot(np.transpose(T[:,:1350]))
plt.plot([1 for i in range(1350)])
plt.legend(['U^sa_1','U^s_1', 'non-robust'])
plt.xlabel('number of states')
plt.ylabel('relative cost to non-robust MDPs')
plt.title('Relative cost for computing robust policy gradient')
plt.tight_layout(pad=0.3)
plt.savefig('asymA1200.jpeg', dpi=1200)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-183a5b631b07> in <module>
#       3 plt.plot([1 for i in range(1350)])
#       4 plt.legend(['U^sa_1','U^s_1', 'non-robust'])
# ----> 5 plt.errorbar()
#       6 plt.xlabel('number of states')
#       7 plt.ylabel('relative cost to non-robust MDPs')
#
# TypeError: errorbar() missing 2 required positional arguments: 'x' and 'y'

# %%
T[:,2]
# Out:
# array([1.34472285, 1.33975372, 1.33125037, ..., 1.33507029, 1.25159949,
#        1.33591838])
